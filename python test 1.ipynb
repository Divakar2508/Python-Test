# %%
#Name:DIVAKAR U
#Roll no: CSA1927



#1


positive=['good','awesome','best','nice']
negative=['worst','awful']
comments=['He is a good boy',
         'Food is the worst here',
         'He is an awesome player',
         'She is the best',
         'This pizza tastes awful',
         'These burger are really nice']
positive_comments=[]
negative_comments=[]
for i in comments:
    k=i.split()
    for j in k:
        if j in positive:
            positive_comments.append(i)
        elif j in negative:
            negative_comments.append(i)
            
print("POSITIVE COMMENTS:")
for i in positive_comments:
    print(i)
print("NEGATIVE COMMENTS:")
for i in negative_comments:
    print(i)
# Out:
# POSITIVE COMMENTS:
# He is a good boy
# He is an awesome player
# She is the best
# These burger are really nice
# NEGATIVE COMMENTS:
# Food is the worst here
# This pizza tastes awful

# %%
#2
import math
dict={'Square':lambda a:a*a,'Cube':lambda a:a*a*a,'Squareroot':lambda a:math.sqrt(a)}
n=int(input("Enter a number:"))
for i in dict.keys():
    print("{}:{}".format(i,dict[i](n)))
# Out:
# Enter a number:4
# Square:16
# Cube:64
# Squareroot:2.0

# %%
#3
fruits=(('Lemon','sour'),('DragonFruit','Sweet'),('Grapes','soUr'),('Kiwi','Sour'),('Apples','Sweet'),('Orange','sour'),('Blueberries','sweet'),('Limes','Sour'))
taste='sour'
l=[]
for i in fruits:
    if(taste==i[1].lower()):
        l.append(i[0])
print("Sour Fruits:")
print(l)
# Out:
# Sour Fruits:
# ['Lemon', 'Grapes', 'Kiwi', 'Orange', 'Limes']

# %%
#4
ls=['hello','Dear','hOw','ARe','You']
l=[]
for i in ls:
    if i[1].isupper():
        l.append(i)
print(l)
# Out:
# ['hOw', 'ARe']

# %%
#5
GMoon=1.622
GEarth=9.81
WeightOnEarth={'John':45,'Shelly':65,'Marry':35}
x=lambda a:"{:.2f}".format((a*GMoon)/GEarth)
for j in WeightOnEarth.keys():
    WeightOnEarth[j]=x(WeightOnEarth[j])
print("WeightOnMoon:{}".format(WeightOnEarth))
# Out:
# WeightOnMoon:{'John': '7.44', 'Shelly': '10.75', 'Marry': '5.79'}

# %%
#6
nameList=['santa Maria','Hello World','Merry christmas','tHank You']
l=[]
for i in nameList:
    k=i.split()
    for j in k:
        if j[0].isupper():
            l.append(j)
print(l)
# Out:
# ['Maria', 'Hello', 'World', 'Merry', 'You']

# %%
#7
given_sets=[[1,2,3,4,8],[2,3,8,5,6],[8,4,5,3,7],[6,9,8,3],[9,12,3,7,6,8,4,6,21,1,6]]
for i in range(len(given_sets)):
    given_sets[i]=set(given_sets[i])
res=given_sets[0]
for j in range(1,len(given_sets)):
    res = res & given_sets[j]
print(res)
# Out:
# {8, 3}

# %%
#8
from itertools import accumulate
li=[9,5,7,8,5]
x=lambda x,y:x+y/2
result=accumulate(li,x)
for res in result:
    print(res)
# Out:
# 9
# 11.5
# 15.0
# 19.0
# 21.5

# %%
#9
Isbool=['True','FALse','tRue','tRue','False','faLse']
l=[]
for i in Isbool:
    l.append(i.upper())
print(l)
# Out:
# ['TRUE', 'FALSE', 'TRUE', 'TRUE', 'FALSE', 'FALSE']

# %%
#10
dateList=['17-12-1997','22-04-2011','01-05-1993','19-06-2020']
print([i.split('-')[2] for i in dateList])
# Out:
# ['1997', '2011', '1993', '2020']
